# %%
import pandas as pd

# %%
df = pd.read_csv("michelin_us_processed_general_dedup_edit.csv")
df.head(1)
# Out:
#       Name                                           Address    Zip  \
# 0  Manresa  320 Village Ln., Los Gatos, 95030, United States  95030
#
#     Location  MinPrice  MaxPrice Currency                    Cuisine  \
# 0  Los Gatos     325.0     325.0      USD  Contemporary, Californian
#
#    Longitude  Latitude PhoneNumber  \
# 0 -121.98071  37.22761       -3276
#
#                                                  Url  \
# 0  https://guide.michelin.com/en/california/los-g...
#
#                            WebsiteUrl             Award  AveragePrice  \
# 0  https://www.manresarestaurant.com/  3 MICHELIN Stars         325.0
#
#   state_id  state_name region General_Category
# 0       CA  California   West     Contemporary

# %%
df[["General_Category", "Sub_Category"]] = df['Cuisine'].str.split(', ', n=1, expand=True)

# %%
df.head()
# Out:
#                   Name                                            Address  \
# 0              Manresa   320 Village Ln., Los Gatos, 95030, United States
# 1        Atelier Crenn  3127 Fillmore St., San Francisco, 94123, Unite...
# 2                 Benu  22 Hawthorne St., San Francisco, 94105, United...
# 3               Quince  470 Pacific Ave., San Francisco, 94133, United...
# 4  Eleven Madison Park    11 Madison Ave., New York, 10010, United States
#
#      Zip       Location  MinPrice  MaxPrice Currency  \
# 0  95030      Los Gatos     325.0     325.0      USD
# 1  94123  San Francisco     298.0     298.0      USD
# 2  94105  San Francisco     350.0     350.0      USD
# 3  94133  San Francisco     360.0     360.0      USD
# 4  10010       New York     125.0     285.0      USD
#
#                      Cuisine   Longitude   Latitude PhoneNumber  \
# 0  Contemporary, Californian -121.980710  37.227610       -3276
# 1       Contemporary, French -122.435860  37.798350         515
# ...

# %%
df.to_csv("michelin_us_processed_subcat.csv", index=False)

# %%
# Yelp dataset for Boston restaurants
df_yelp = pd.read_json("yelp_academic_dataset_business.json", lines=True)

# %%
df_yelp.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# ...

# %%
df_yelp_filtered = df_yelp[df_yelp["stars"] == 5.0]

# %%
df_yelp_filtered = df_yelp_filtered[df_yelp_filtered["state"] == "MA"]

# %%
df_yelp_filtered = df_yelp[df_yelp["city"] == "Affton"]

# %%
df_yelp_filtered
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []
